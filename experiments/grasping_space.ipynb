# %%
# Cell 1: Import necessary libraries
import numpy as np
import os
import time
from pydrake.all import (
    DiagramBuilder, AddMultibodyPlantSceneGraph, Parser, RigidTransform, RotationMatrix,
    Role, MeshcatVisualizer, StartMeshcat, RationalForwardKinematics, CspaceFreePolytope,
    SeparatingPlaneOrder, Rgba, InverseKinematics, RollPitchYaw,
    LinearEqualityConstraint, Sphere, Parallelism, AddDefaultVisualization, 
    ConnectPlanarSceneGraphVisualizer, IrisFromCliqueCoverOptions, 
    IrisInConfigurationSpaceFromCliqueCover, RandomGenerator, RobotDiagramBuilder, 
    SceneGraphCollisionChecker, MultibodyPlant, SceneGraph, 
    SolverOptions, CommonSolverOption, GeometrySet, ScsSolver
)
from pydrake.geometry.optimization import GraphOfConvexSetsOptions, HPolyhedron, VPolytope, Point, Hyperellipsoid
from pydrake.geometry.optimization import ConvexHull as DrakeConvexHull
from pydrake.planning import GcsTrajectoryOptimization
from pydrake.solvers import MathematicalProgram, Solve, MosekSolver
from pydrake.trajectories import CompositeTrajectory
from pydrake.common import FindResourceOrThrow
from scipy.spatial import ConvexHull
import mcubes
from functools import partial
import matplotlib.pyplot as plt
from ipywidgets import widgets
import quadprog

from pathlib import Path
import sys

# add the parent directory of this notebook to the import path
parent = Path.cwd().parent
if str(parent) not in sys.path:
    sys.path.insert(0, str(parent))

from ciris_plant_visualizer import CIrisPlantVisualizer

# %%
# Cell 2: Set up the plant and scene graph, and initialize the CIrisPlantVisualizer
# builder = DiagramBuilder()
# plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
# parser = Parser(plant, scene_graph)
# parser.SetAutoRenaming(True)

print("Setting up the plant and scene graph...")

# Replace DiagramBuilder with RobotDiagramBuilder
builder = RobotDiagramBuilder(time_step=0.0)
plant = builder.plant()
scene_graph = builder.scene_graph()
parser = Parser(plant, scene_graph)
parser.SetAutoRenaming(True)
# Out:
# Setting up the plant and scene graph...

# %%
# Add the robot
# gripper = parser.AddModels(file_name="../my_sdfs/wsg_2dof.sdf")[0]

print("Loading Panda robot models...")

# --- Add the Panda arm + hand ---
panda_arm  = parser.AddModels(url="package://drake_models/franka_description/urdf/panda_arm.urdf")[0]
panda_hand = parser.AddModels(url="package://drake_models/franka_description/urdf/panda_hand.urdf")[0]

print("Welding Panda arm and hand...")

# Weld arm base to world (identity)
plant.WeldFrames(
    plant.world_frame(),
    plant.GetFrameByName("panda_link0", panda_arm),
    RigidTransform())

# Weld hand to arm flange with X_PC: translation [0,0,0], RPY deg [0,0,-45]
X_8H = RigidTransform(RollPitchYaw(0.0, 0.0, -np.deg2rad(45.0)), [0.0, 0.0, 0.0])
plant.WeldFrames(
    plant.GetFrameByName("panda_link8", panda_arm),        # parent (P)
    plant.GetFrameByName("panda_hand", panda_hand),    # child  (C)
    X_8H)

print("Setting default finger joint positions...")

# Optional: set the default finger opening (each finger is a prismatic joint).
# 0.02 m on each finger → ~0.04 m total width. Adjust to taste.
for j in ["panda_finger_joint1", "panda_finger_joint2"]:
    plant.GetJointByName(j, panda_hand).set_default_translation(0.02)
# Out:
# Loading Panda robot models...
# Welding Panda arm and hand...
# Setting default finger joint positions...

# %%
print("Adding the bottle cap and obstacles...")

cap = parser.AddModels(file_name="../my_sdfs/bottle_cap.sdf")[0]
# obstacle1 = parser.AddModels("../my_sdfs/obstacle.sdf")[0]
# # obstacle2 = parser.AddModels("my_sdfs/obstacle.sdf")[0]
# obstacle3 = parser.AddModels("../my_sdfs/obstacle.sdf")[0]

# Set welds
plant.WeldFrames(
    plant.world_frame(), 
    plant.GetFrameByName("base_link", cap),
    RigidTransform(RotationMatrix(), [0.5, 0, 0]))

# # Weld the obstacle to the world frame (adjust pose as needed)
# obstacle_pose1 = RigidTransform(RotationMatrix(), [0.51, 0.035, 0.02])  # Adjust position
# plant.WeldFrames(
#     plant.world_frame(),
#     plant.GetFrameByName("obstacle_link", obstacle1),
#     obstacle_pose1)

# # obstacle_pose2 = RigidTransform(RotationMatrix(), [-0.025, 0.05, 0.02])  # Adjust position
# # plant.WeldFrames(
# #     plant.world_frame(),
# #     plant.GetFrameByName("obstacle_link", obstacle2),
# #     obstacle_pose2)

# obstacle_pose3 = RigidTransform(RotationMatrix(), [0.465, -0.005, 0.02])  # Adjust position
# plant.WeldFrames(
#     plant.world_frame(),
#     plant.GetFrameByName("obstacle_link", obstacle3),
#     obstacle_pose3)
# Out:
# Adding the bottle cap and obstacles...
# <WeldJoint name='world_welds_to_base_link' index=14 model_instance=4>

# %%
print("Finalising plant...")
print("Bodies:", plant.num_bodies(), "Joints:", plant.num_joints())


plant.Finalize()

inspector = scene_graph.model_inspector()
num_frames = len(list(inspector.GetAllFrameIds()))
num_geoms = sum(inspector.NumGeometriesForFrame(fid) for fid in inspector.GetAllFrameIds())
print("Frames:", num_frames, "Geometries:", num_geoms)


print("Plant finalised.")

print("Number of positions: ", plant.num_positions())

# Cell 3: Initialize the CIrisPlantVisualizer
q_star = np.zeros(plant.num_positions())


print("Initialising CspaceFreePolytope...")

# The object we will use to perform our certification
cspace_free_polytope = CspaceFreePolytope(
    plant, 
    scene_graph,
    SeparatingPlaneOrder.kAffine,
    q_star)

print("Initializing CIrisPlantVisualizer...")

visualizer = CIrisPlantVisualizer(
    plant,
    builder,
    scene_graph,
    cspace_free_polytope,
    viz_role=Role.kIllustration,
    allow_plus_3dof=True
)

print("Setting up the visualizer...")

visualizer.task_space_diagram.ForcedPublish(visualizer.task_space_diagram_context)
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7001
# Finalising plant...
# Bodies: 16 Joints: 15
# Frames: 16 Geometries: 90
# Plant finalised.
# Number of positions:  10
# Initialising CspaceFreePolytope...
# Initializing CIrisPlantVisualizer...
# Visualisations won't work properly. Can't visualize the TC-Space of plants with more than 3-DOF. The first 3 DOF from the plant will be visualized
# Setting up the visualizer...

# %%
sliders = []

plant_context = visualizer.plant_context
diagram = visualizer.task_space_diagram
diagram_context = visualizer.task_space_diagram_context

for i in range(plant.num_positions()):
    q_low = plant.GetPositionLowerLimits()[i]
    q_high = plant.GetPositionUpperLimits()[i]
    step = (q_high - q_low) / 100
    sliders.append(widgets.FloatSlider(
        min=q_low, max=q_high, 
        value=0, step=step, 
        description=f"q{i}"))
    
q = np.zeros(plant.num_positions())
# q = [-3.14, -0.78, -0.03]
def handle_slider_change(change, idx):
    q[idx] = change['new']
    print(visualizer.check_collision_q_by_ik(q))
    plant.SetPositions(plant_context, q)
    diagram.ForcedPublish(diagram_context)
    
idx = 0
for slider in sliders:
    slider.observe(partial(handle_slider_change, idx = idx), names='value')
    idx+=1

for slider in sliders:
    display(slider)
# Out:
# FloatSlider(value=0.0, description='q0', max=2.8973, min=-2.8973, step=0.057946)
# FloatSlider(value=0.0, description='q1', max=1.7628, min=-1.7628, step=0.035255999999999996)
# FloatSlider(value=0.0, description='q2', max=2.8973, min=-2.8973, step=0.057946)
# FloatSlider(value=-0.0698, description='q3', max=-0.0698, min=-3.0718, step=0.03002)
# FloatSlider(value=0.0, description='q4', max=2.8973, min=-2.8973, step=0.057946)
# FloatSlider(value=0.0, description='q5', max=3.7525, min=-0.0175, step=0.0377)
# FloatSlider(value=0.0, description='q6', max=2.8973, min=-2.8973, step=0.057946)
# FloatSlider(value=0.0, description='q7', max=0.0, min=-0.045, step=0.00045)
# FloatSlider(value=0.0, description='q8', max=0.045, step=0.00045)
# FloatSlider(value=0.0, description='q9', max=3.14, min=-3.14, step=0.06280000000000001)

# %%
# Keep only the gripper rotation, fingers, and cap rotation free.
# The arm joints 1-6 will be locked later at the grasp configuration.
free_joint_names = [
    "panda_joint7",
    "panda_finger_joint1",
    "panda_finger_joint2",
    "cap_to_base",
]
locked_arm_joint_names = [f"panda_joint{i}" for i in range(1, 7)]


def lock_arm_to_lower_dim_manifold(q_nominal):
    plant.SetPositions(plant_context, q_nominal)

    for joint_name in locked_arm_joint_names:
        plant.GetJointByName(joint_name, panda_arm).Lock(plant_context)

    diagram.ForcedPublish(diagram_context)
    print("Locked arm joints:", locked_arm_joint_names)
    print("Free manifold joints:", free_joint_names)

# %% [markdown]
# ## Get Grasping Configuration Through IK

# %%
import numpy as np
from pydrake.math import RigidTransform, RotationMatrix
from pydrake.multibody.inverse_kinematics import InverseKinematics
from pydrake.solvers import Solve, SnoptSolver, IpoptSolver, OsqpSolver, ScsSolver

def solve_ik_place_frame_at_pose(
    # visualizer,
    plant,
    plant_context,
    frame_B,                                # the frame you want to place (e.g., panda_hand)
    X_WG: RigidTransform,                   # desired pose of frame_B in world
    pos_tol=1e-3,                           # box half-width [m]
    theta_tol=np.deg2rad(2),                # angular tolerance [rad]
    min_distance=None,                      # e.g., 1e-3 to keep clearance; None to ignore
    q_seed=None,                            # seed configuration
):
    
    ik = InverseKinematics(plant, plant_context)
    q = ik.q()

    # Position: keep the origin of frame_B in a small box around X_WG.translation()
    p_BQ_B = np.zeros(3)
    p = X_WG.translation()
    ik.AddPositionConstraint(
        frameB=frame_B, p_BQ=p_BQ_B,
        frameA=plant.world_frame(),
        p_AQ_lower=p - pos_tol, p_AQ_upper=p + pos_tol
    )

    # Orientation: bound frame_B’s rotation to the desired world rotation
    # This constrains angle between R_WB and X_WG.rotation() to be <= theta_tol.    
    ik.AddOrientationConstraint(
    frameAbar=plant.world_frame(),            # Ā
    R_AbarA=X_WG.rotation(),                  # desired world rotation
    frameBbar=frame_B,                        # B̄ = your hand frame
    R_BbarB=RotationMatrix(),                 # identity in B
    theta_bound=theta_tol                     # radians
)


    # Optional collision clearance (uses Proximity role; can be conservative for grasps)
    if min_distance is not None:
        ik.AddMinimumDistanceLowerBoundConstraint(min_distance)

    prog = ik.prog()
    if q_seed is None:
        q_seed = plant.GetPositions(plant_context)
    prog.SetInitialGuess(q, q_seed)

    # Pick an available solver. Orientation makes this nonlinear; SNOPT/IPOPT are best.
    result = Solve(prog)
    if not result.is_success():
        # try a second pass with a looser theta or different seed before giving up
        return None, result

    q_sol = result.GetSolution(q)

    return q_sol, result

# %%
# Build diagram/contexts as you already do
plant_context = visualizer.plant_context
diagram = visualizer.task_space_diagram
diagram_context = visualizer.task_space_diagram_context

# Frames and goal pose
E   = plant.GetFrameByName("panda_hand", panda_hand)   # tool frame
Cap = plant.GetFrameByName("base_link", cap)           # cap frame

# World poses
X_WCap = plant.CalcRelativeTransform(plant_context, plant.world_frame(), Cap)

# Choose a grasp goal: 65 mm above cap origin (same orientation as Cap here)
# Rotate by 180 deg upside down
R_CapGoal = RotationMatrix(RollPitchYaw(np.pi, 0, 0))
X_CapGoal = RigidTransform(R_CapGoal, [0.0, 0.0, 0.105])
X_WG = X_WCap.multiply(X_CapGoal)  # desired world pose for the hand frame

# (Optional) lock fingers during IK
for jn in ["panda_finger_joint1", "panda_finger_joint2"]:
    plant.GetJointByName(jn, panda_hand).Lock(plant_context)

# Solve IK (function from previous message)
q_sol, res = solve_ik_place_frame_at_pose(
    # visualizer=visualizer,
    plant=plant,
    plant_context=plant_context,
    frame_B=E,
    X_WG=X_WG,
    pos_tol=0.0,
    theta_tol=np.deg2rad(0),
    min_distance=None,
    q_seed=plant.GetPositions(plant_context)
)

if q_sol is None:
    print("IK failed:", res.get_solver_id().name())
else:
    plant.SetPositions(plant_context, q_sol)
    diagram.ForcedPublish(diagram_context)
    print("IK succeeded. New q:", q_sol)
# Out:
# IK succeeded. New q: [-1.28718907e+00  1.31290357e+00  1.18527863e+00 -2.21273568e+00
#  -1.58448521e+00  2.03056033e+00  1.66313360e+00 -2.40000000e-02
#   2.40000000e-02  8.88178420e-16]

# %%
plant.SetPositions(plant_context, q_star)
diagram.ForcedPublish(diagram_context)

# %%
# q: [-1.28718907e+00  1.31290357e+00  1.18527863e+00 -2.21273568e+00
#  -1.58448521e+00  2.03056033e+00  1.66303822e+00 -2.40000000e-02
#   2.40000000e-02  8.88178420e-16]

q_grasp = np.array([-1.28718907e+00,  
                    1.31290357e+00,  
                    1.18527863e+00, 
                    -2.21273568e+00,
                    -1.58448521e+00,  
                    2.03056033e+00,  
                    1.66303822e+00,
                    -2.40000000e-02,
                    2.40000000e-02,
                    8.88178420e-16])
plant.SetPositions(plant_context, q_grasp)
diagram.ForcedPublish(diagram_context)

# %%
# Freeze arm joints 1-6 at the grasp pose and leave joint 7, both fingers,
# and the cap rotation free. This defines the lower-dimensional manifold we
# will use for free-space generation.
lock_arm_to_lower_dim_manifold(q_grasp)

# Re-center the stereographic projection and free polytope around the grasp pose.
q_star = q_grasp.copy()
visualizer.q_star = q_star
visualizer.s_lower_limits = visualizer.rat_forward_kin.ComputeSValue(
    visualizer.q_lower_limits, q_star)
visualizer.s_upper_limits = visualizer.rat_forward_kin.ComputeSValue(
    visualizer.q_upper_limits, q_star)

cspace_free_polytope = CspaceFreePolytope(
    plant,
    scene_graph,
    SeparatingPlaneOrder.kAffine,
    q_star,
)
visualizer.cspace_free_polytope = cspace_free_polytope
visualizer.plane_indices = np.arange(0, len(cspace_free_polytope.separating_planes()))
# Out:
# Locked arm joints: ['panda_joint1', 'panda_joint2', 'panda_joint3', 'panda_joint4', 'panda_joint5', 'panda_joint6']
# Free manifold joints: ['panda_joint7', 'panda_finger_joint1', 'panda_finger_joint2', 'cap_to_base']

# %% [markdown]
# ## Grasping Configuration checker

# %% [markdown]
# Hand frame must be located at a certain height range from the cap (and rotation, so a transform), fingers at an offset (also a range) and allow full rotation of gripper hand and cap

# %%
# Get panda_hand frame between 0.0105 m and 0.11 m above the cap base_link frame
# Fingers should be open between 0.024 and 0.025 m and -0.024 and -0.025 m
# Get a function that checks whether these constraints are satisfied

def check_grasp_constraints(q):
    old_q = plant.GetPositions(plant_context)
    plant.SetPositions(plant_context, q)
    # diagram.ForcedPublish(diagram_context)
    
    # Get the current pose of the hand frame
    X_WE = plant.CalcRelativeTransform(plant_context, plant.world_frame(), E)
    X_WCap = plant.CalcRelativeTransform(plant_context, plant.world_frame(), Cap)
    
    # Compute the relative transform from Cap to E
    X_CapE = X_WCap.inverse().multiply(X_WE)
    
    z_height = X_CapE.translation()[2]
    
    right_finger_joint = plant.GetJointByName("panda_finger_joint1", panda_hand)
    left_finger_joint  = plant.GetJointByName("panda_finger_joint2", panda_hand)
    
    right_finger_pos = right_finger_joint.get_translation(plant_context)
    left_finger_pos  = left_finger_joint.get_translation(plant_context)
    
    # Check height constraint
    height_ok = 0.0105 <= z_height <= 0.11
    
    # Check finger opening constraints
    fingers_ok = (-0.025 <= right_finger_pos <= -0.024) and (0.024 <= left_finger_pos <= 0.025)
    
    # Restore old q
    plant.SetPositions(plant_context, old_q)
    diagram.ForcedPublish(diagram_context)
    
    return height_ok and fingers_ok, z_height, right_finger_pos, left_finger_pos

# %%
print("Checking grasp constraints for q_grasp:", check_grasp_constraints(q_grasp))
# Out:
# Checking grasp constraints for q_grasp: (True, np.float64(0.10500008908564608), -0.024, 0.024)

# %% [markdown]
# # Generate C-free for full franka arm with IRIS-ZO

# %%
builder = visualizer.builder
plant = visualizer.plant
scene_graph = visualizer.scene_graph
q_star = visualizer.q_star
rat_fk = visualizer.rat_forward_kin
inspector = visualizer.model_inspector
diagram = visualizer.task_space_diagram
context = visualizer.task_space_diagram_context
cspace_free_polytope = visualizer.cspace_free_polytope

# %%
from pydrake.all import IrisZoOptions, IrisNp2Options, CommonSampledIrisOptions, IrisFromCliqueCoverOptions, IrisInConfigurationSpaceFromCliqueCover
import logging

# from pydrake.all import set_log_level
# set_log_level("warn")
# logging.getLogger("pydrake").setLevel(logging.WARNING)

# %%
model_instances = [plant.GetModelInstanceByName("panda"), plant.GetModelInstanceByName("panda_hand"), plant.GetModelInstanceByName("bottle_cap")]

generator = RandomGenerator(1234)
checker = SceneGraphCollisionChecker(
    model=diagram,
    robot_model_instances=model_instances,
    edge_step_size=0.01,
)


common_sampled_iris_options = CommonSampledIrisOptions()
# common_sampled_iris_options.num_particles = 1000
# common_sampled_iris_options.tau = 0.5
common_sampled_iris_options.delta = 0.05
common_sampled_iris_options.epsilon = 0.01
common_sampled_iris_options.max_iterations = 10
# common_sampled_iris_options.max_iterations_separating_planes = 20
# common_sampled_iris_options.max_separating_planes_per_iteration = 10
parallelism = Parallelism(32)
common_sampled_iris_options.parallelism = parallelism
common_sampled_iris_options.verbose = True
# common_sampled_iris_options.require_sample_point_is_contained = True
common_sampled_iris_options.configuration_space_margin = 0.00001
# common_sampled_iris_options.relax_margin = True
common_sampled_iris_options.termination_threshold = 1e-5
common_sampled_iris_options.relative_termination_threshold = 1e-4
common_sampled_iris_options.remove_all_collisions_possible = False
# common_sampled_iris_options.random_seed = 1234
# common_sampled_iris_options.mixing_steps = 50
# common_sampled_iris_options.sample_particles_in_parallel = False


iris_zo_options = IrisZoOptions()
iris_zo_options.bisection_steps=30
iris_zo_options.sampled_iris_options=common_sampled_iris_options

# iris_np2_options = IrisNp2Options()
# iris_np2_options.sampled_iris_options = common_sampled_iris_options

options = IrisFromCliqueCoverOptions()
options.num_points_per_visibility_round = 200
options.coverage_termination_threshold = 0.9
options.parallelism = parallelism
# options.iris_options.configuration_space_margin = 0.0001
options.iris_options = iris_zo_options
# options.iris_options = iris_np2_options
# See https://github.com/RobotLocomotion/drake/issues/21343
regions = IrisInConfigurationSpaceFromCliqueCover(checker, options, generator, [])

print("\nnumber of regions: ", len(regions))


# visualizer.visualize_collision_constraint(factor=1, num_points=30, filled_polytopes=regions)
# Out:
# INFO:drake:Allocating contexts to support implicit context parallelism 32
# INFO:drake:Current Fraction of Domain Covered = 0
# INFO:drake:IrisFromCliqueCover Iteration 1/100
# INFO:drake:IrisZo using 32 threads.
# INFO:drake:IrisZo finding region that is 0.01 collision free with 0.95 certainty using up to 11670 particles.
# INFO:drake:IrisZo worst case test requires 11670 samples.
# INFO:drake:IrisZo outer iteration 0
# INFO:drake:IrisZo N_test 3193, N_col 249, thresh 15.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 4302, N_col 272, thresh 21.51
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 4951, N_col 189, thresh 24.755
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 5411, N_col 59, thresh 27.055
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 5768, N_col 37, thresh 28.84
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6060, N_col 116, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 6306, N_col 111, thresh 31.53
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6520, N_col 71, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6708, N_col 44, thresh 33.54
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6877, N_col 23, thresh 34.385
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 1
# INFO:drake:IrisZo N_test 4302, N_col 565, thresh 21.51
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 5411, N_col 349, thresh 27.055
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6060, N_col 260, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6520, N_col 318, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6877, N_col 176, thresh 34.385
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7169, N_col 211, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 7415, N_col 177, thresh 37.075
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7629, N_col 44, thresh 38.145
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7818, N_col 161, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7986, N_col 92, thresh 39.93
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8139, N_col 37, thresh 40.695
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 2
# INFO:drake:IrisZo N_test 4951, N_col 506, thresh 24.755
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 6060, N_col 449, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6708, N_col 368, thresh 33.54
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7169, N_col 256, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7526, N_col 349, thresh 37.63
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7818, N_col 256, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 8064, N_col 240, thresh 40.32
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 79, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8466, N_col 120, thresh 42.33
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 78, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8787, N_col 108, thresh 43.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 8927, N_col 140, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9055, N_col 110, thresh 45.275
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9173, N_col 95, thresh 45.865
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9284, N_col 110, thresh 46.42
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9387, N_col 33, thresh 46.935
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 3
# INFO:drake:IrisZo N_test 5411, N_col 554, thresh 27.055
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 6520, N_col 552, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7169, N_col 407, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7629, N_col 501, thresh 38.145
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7986, N_col 291, thresh 39.93
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 222, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 8524, N_col 269, thresh 42.62
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8738, N_col 204, thresh 43.69
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8927, N_col 149, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9095, N_col 49, thresh 45.475
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9248, N_col 118, thresh 46.24
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 9387, N_col 119, thresh 46.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9515, N_col 125, thresh 47.575
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9633, N_col 92, thresh 48.165
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9744, N_col 45, thresh 48.72
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 4
# INFO:drake:IrisZo N_test 5768, N_col 511, thresh 28.84
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 6877, N_col 415, thresh 34.385
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7526, N_col 333, thresh 37.63
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7986, N_col 376, thresh 39.93
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8343, N_col 311, thresh 41.715
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 371, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 8881, N_col 194, thresh 44.405
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9095, N_col 183, thresh 45.475
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9284, N_col 185, thresh 46.42
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9452, N_col 187, thresh 47.26
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9605, N_col 145, thresh 48.025
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 9744, N_col 105, thresh 48.72
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9872, N_col 82, thresh 49.36
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9990, N_col 130, thresh 49.95
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10101, N_col 71, thresh 50.505
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10204, N_col 87, thresh 51.02
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 10301, N_col 102, thresh 51.505
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10393, N_col 64, thresh 51.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10479, N_col 88, thresh 52.395
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10561, N_col 116, thresh 52.805
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# WARNING:drake:IrisZo WARNING, separating planes hit max iterations without passing the unadaptive test, this voids the probabilistic guarantees!
# INFO:drake:IrisZo outer iteration 5
# INFO:drake:IrisZo N_test 6060, N_col 632, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 7169, N_col 626, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7818, N_col 372, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 288, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 112, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8927, N_col 302, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 9173, N_col 153, thresh 45.865
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9387, N_col 266, thresh 46.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9575, N_col 175, thresh 47.875
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9744, N_col 138, thresh 48.72
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9896, N_col 71, thresh 49.480000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 10036, N_col 106, thresh 50.18
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10164, N_col 224, thresh 50.82
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10282, N_col 132, thresh 51.410000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10393, N_col 87, thresh 51.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10496, N_col 104, thresh 52.480000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 10593, N_col 78, thresh 52.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10684, N_col 87, thresh 53.42
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10771, N_col 85, thresh 53.855000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10853, N_col 44, thresh 54.265
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 6
# INFO:drake:IrisZo N_test 6306, N_col 714, thresh 31.53
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 7415, N_col 375, thresh 37.075
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8064, N_col 375, thresh 40.32
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8524, N_col 309, thresh 42.62
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8881, N_col 390, thresh 44.405
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9173, N_col 352, thresh 45.865
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 9420, N_col 217, thresh 47.1
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9633, N_col 312, thresh 48.165
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9822, N_col 173, thresh 49.11
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9990, N_col 211, thresh 49.95
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10143, N_col 137, thresh 50.715
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 10282, N_col 170, thresh 51.410000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10410, N_col 112, thresh 52.050000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10529, N_col 57, thresh 52.645
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10639, N_col 118, thresh 53.195
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10743, N_col 126, thresh 53.715
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 10840, N_col 120, thresh 54.2
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10931, N_col 85, thresh 54.655
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11017, N_col 92, thresh 55.085
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11100, N_col 60, thresh 55.5
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# WARNING:drake:IrisZo WARNING, separating planes hit max iterations without passing the unadaptive test, this voids the probabilistic guarantees!
# INFO:drake:IrisZo outer iteration 7
# INFO:drake:IrisZo N_test 6520, N_col 648, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 7629, N_col 532, thresh 38.145
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 495, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8738, N_col 460, thresh 43.69
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9095, N_col 437, thresh 45.475
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9387, N_col 357, thresh 46.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 9633, N_col 250, thresh 48.165
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9847, N_col 229, thresh 49.235
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10036, N_col 281, thresh 50.18
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10204, N_col 138, thresh 51.02
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10357, N_col 278, thresh 51.785000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 10496, N_col 98, thresh 52.480000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10624, N_col 124, thresh 53.120000000000005
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10743, N_col 98, thresh 53.715
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10853, N_col 105, thresh 54.265
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10956, N_col 105, thresh 54.78
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 11053, N_col 109, thresh 55.265
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11145, N_col 99, thresh 55.725
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11231, N_col 132, thresh 56.155
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11313, N_col 78, thresh 56.565
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# WARNING:drake:IrisZo WARNING, separating planes hit max iterations without passing the unadaptive test, this voids the probabilistic guarantees!
# INFO:drake:IrisZo outer iteration 8
# INFO:drake:IrisZo N_test 6708, N_col 556, thresh 33.54
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 7818, N_col 719, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8466, N_col 471, thresh 42.33
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8927, N_col 333, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9284, N_col 326, thresh 46.42
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9575, N_col 228, thresh 47.875
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 9822, N_col 306, thresh 49.11
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10036, N_col 247, thresh 50.18
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10224, N_col 152, thresh 51.120000000000005
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10393, N_col 110, thresh 51.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10545, N_col 90, thresh 52.725
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 10684, N_col 112, thresh 53.42
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10812, N_col 131, thresh 54.06
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10931, N_col 72, thresh 54.655
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11041, N_col 120, thresh 55.205
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11145, N_col 72, thresh 55.725
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 11242, N_col 72, thresh 56.21
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 11333, N_col 23, thresh 56.665
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo delta vol -0.11539592798597953, threshold 1e-05
# INFO:drake:IrisZo execution time : 35348 ms
# INFO:drake:IrisFromCliqueCover Iteration 2/100
# INFO:drake:IrisZo using 32 threads.
# INFO:drake:IrisZo finding region that is 0.01 collision free with 0.95 certainty using up to 11670 particles.
# INFO:drake:IrisZo worst case test requires 11670 samples.
# INFO:drake:IrisZo outer iteration 0
# INFO:drake:IrisZo N_test 3193, N_col 249, thresh 15.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 4302, N_col 278, thresh 21.51
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 4951, N_col 365, thresh 24.755
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 5411, N_col 254, thresh 27.055
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 5768, N_col 240, thresh 28.84
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6060, N_col 159, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 6306, N_col 121, thresh 31.53
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6520, N_col 128, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6708, N_col 50, thresh 33.54
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6877, N_col 73, thresh 34.385
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7030, N_col 61, thresh 35.15
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 7169, N_col 29, thresh 35.845
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 1
# INFO:drake:IrisZo N_test 4302, N_col 326, thresh 21.51
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 5411, N_col 329, thresh 27.055
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6060, N_col 382, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6520, N_col 342, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6877, N_col 365, thresh 34.385
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7169, N_col 209, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 7415, N_col 175, thresh 37.075
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7629, N_col 173, thresh 38.145
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7818, N_col 107, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7986, N_col 192, thresh 39.93
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8139, N_col 204, thresh 40.695
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 8278, N_col 157, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8406, N_col 145, thresh 42.03
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8524, N_col 115, thresh 42.62
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 102, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8738, N_col 80, thresh 43.69
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 8835, N_col 63, thresh 44.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8927, N_col 99, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9013, N_col 117, thresh 45.065
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9095, N_col 138, thresh 45.475
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# WARNING:drake:IrisZo WARNING, separating planes hit max iterations without passing the unadaptive test, this voids the probabilistic guarantees!
# INFO:drake:IrisZo outer iteration 2
# INFO:drake:IrisZo N_test 4951, N_col 560, thresh 24.755
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 6060, N_col 484, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 6708, N_col 533, thresh 33.54
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7169, N_col 337, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7526, N_col 313, thresh 37.63
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7818, N_col 404, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 8064, N_col 288, thresh 40.32
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 235, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8466, N_col 191, thresh 42.33
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 147, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8787, N_col 101, thresh 43.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 8927, N_col 156, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9055, N_col 142, thresh 45.275
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9173, N_col 43, thresh 45.865
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo outer iteration 3
# INFO:drake:IrisZo N_test 5411, N_col 482, thresh 27.055
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 6520, N_col 500, thresh 32.6
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7169, N_col 427, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7629, N_col 541, thresh 38.145
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7986, N_col 406, thresh 39.93
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 255, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 8524, N_col 154, thresh 42.62
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8738, N_col 259, thresh 43.69
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8927, N_col 162, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9095, N_col 125, thresh 45.475
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9248, N_col 296, thresh 46.24
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 9387, N_col 194, thresh 46.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9515, N_col 161, thresh 47.575
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9633, N_col 144, thresh 48.165
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9744, N_col 101, thresh 48.72
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9847, N_col 116, thresh 49.235
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 9944, N_col 99, thresh 49.72
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10036, N_col 75, thresh 50.18
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10122, N_col 124, thresh 50.61
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10204, N_col 90, thresh 51.02
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# WARNING:drake:IrisZo WARNING, separating planes hit max iterations without passing the unadaptive test, this voids the probabilistic guarantees!
# INFO:drake:IrisZo outer iteration 4
# INFO:drake:IrisZo N_test 5768, N_col 577, thresh 28.84
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 6877, N_col 424, thresh 34.385
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7526, N_col 345, thresh 37.63
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7986, N_col 369, thresh 39.93
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8343, N_col 315, thresh 41.715
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 211, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 8881, N_col 293, thresh 44.405
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9095, N_col 233, thresh 45.475
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9284, N_col 203, thresh 46.42
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9452, N_col 203, thresh 47.26
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9605, N_col 204, thresh 48.025
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 9744, N_col 138, thresh 48.72
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9872, N_col 163, thresh 49.36
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9990, N_col 102, thresh 49.95
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10101, N_col 129, thresh 50.505
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10204, N_col 89, thresh 51.02
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 16 faces: 180
# INFO:drake:IrisZo N_test 10301, N_col 83, thresh 51.505
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10393, N_col 79, thresh 51.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10479, N_col 116, thresh 52.395
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10561, N_col 68, thresh 52.805
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# WARNING:drake:IrisZo WARNING, separating planes hit max iterations without passing the unadaptive test, this voids the probabilistic guarantees!
# INFO:drake:IrisZo outer iteration 5
# INFO:drake:IrisZo N_test 6060, N_col 532, thresh 30.3
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 1 faces: 30
# INFO:drake:IrisZo N_test 7169, N_col 501, thresh 35.845
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 7818, N_col 396, thresh 39.09
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8278, N_col 337, thresh 41.39
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8635, N_col 321, thresh 43.175000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 8927, N_col 123, thresh 44.635
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 6 faces: 80
# INFO:drake:IrisZo N_test 9173, N_col 160, thresh 45.865
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9387, N_col 181, thresh 46.935
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9575, N_col 191, thresh 47.875
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9744, N_col 178, thresh 48.72
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 9896, N_col 171, thresh 49.480000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:SeparatingPlanes iteration: 11 faces: 130
# INFO:drake:IrisZo N_test 10036, N_col 130, thresh 50.18
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10164, N_col 108, thresh 50.82
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10282, N_col 62, thresh 51.410000000000004
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10393, N_col 72, thresh 51.965
# INFO:drake:IrisZo probabilistic test failed! Continuing to compute hyperplanes.
# INFO:drake:IrisZo N_test 10496, N_col 50, thresh 52.480000000000004
# INFO:drake:IrisZo probabilistic test passed! Finished computing hyperplanes.
# INFO:drake:IrisZo delta vol -0.1577146154098319, threshold 1e-05
# INFO:drake:IrisZo execution time : 22537 ms
# number of regions:  2

# %%
regions
# Out:
# [<pydrake.geometry.optimization.HPolyhedron at 0x74fc47405e70>,
#  <pydrake.geometry.optimization.HPolyhedron at 0x74fc47405f70>]

# %%
for i, region in enumerate(regions):
    print(f"Region {i}:")
    # print("  planes:", region.A())
    print("  Shape:", region.A().shape)
    # print("  b:", region.b())
    print("  Shape:", region.b().shape)
# Out:
# Region 0:
#   Shape: (190, 10)
#   Shape: (190,)
# Region 1:
#   Shape: (170, 10)
#   Shape: (170,)

# %%
print("Plant num positions:", plant.num_positions())
print("Position names:")
for i, name in enumerate(plant.GetPositionNames()):
    print(i, name)
# Out:
# Plant num positions: 10
# Position names:
# 0 panda_panda_joint1_q
# 1 panda_panda_joint2_q
# 2 panda_panda_joint3_q
# 3 panda_panda_joint4_q
# 4 panda_panda_joint5_q
# 5 panda_panda_joint6_q
# 6 panda_panda_joint7_q
# 7 panda_hand_panda_finger_joint1_x
# 8 panda_hand_panda_finger_joint2_x
# 9 bottle_cap_cap_to_base_q

# %%
def joint_position_index(plant, joint_name, model_instance=None):
    if model_instance is None:
        joint = plant.GetJointByName(joint_name)
    else:
        joint = plant.GetJointByName(joint_name, model_instance)

    if joint.num_positions() != 1:
        raise ValueError(
            f"Joint {joint_name} has {joint.num_positions()} positions; "
            "this helper assumes a 1-DOF joint."
        )

    return joint.position_start()


active_indices = [
    joint_position_index(plant, "panda_joint7", panda_arm),
    joint_position_index(plant, "panda_finger_joint1", panda_hand),
    joint_position_index(plant, "panda_finger_joint2", panda_hand),
    joint_position_index(plant, "cap_to_base", cap)
]

active_indices = list(active_indices)
fixed_indices = [i for i in range(plant.num_positions()) if i not in active_indices]

print("Active indices:", active_indices)
print("Fixed indices:", fixed_indices)

for i, name in enumerate(plant.GetPositionNames()):
    tag = "ACTIVE" if i in active_indices else "fixed"
    print(f"{i:2d}: {name:40s} {tag}")
# Out:
# Active indices: [6, 7, 8, 9]
# Fixed indices: [0, 1, 2, 3, 4, 5]
#  0: panda_panda_joint1_q                     fixed
#  1: panda_panda_joint2_q                     fixed
#  2: panda_panda_joint3_q                     fixed
#  3: panda_panda_joint4_q                     fixed
#  4: panda_panda_joint5_q                     fixed
#  5: panda_panda_joint6_q                     fixed
#  6: panda_panda_joint7_q                     ACTIVE
#  7: panda_hand_panda_finger_joint1_x         ACTIVE
#  8: panda_hand_panda_finger_joint2_x         ACTIVE
#  9: bottle_cap_cap_to_base_q                 ACTIVE

# %%
assert q_grasp.shape[0] == plant.num_positions()

def make_full_dimensional_slice_box(
    plant,
    q_fixed,
    active_indices,
    fixed_half_width=1e-4, 
    default_revolute_bound=np.pi,
):
    nq = plant.num_positions()

    lb = plant.GetPositionLowerLimits().copy()
    ub = plant.GetPositionUpperLimits().copy()

    active_set = set(active_indices)

    for i in range(nq):
        if i not in active_set:
            lb[i] = q_fixed[i] - fixed_half_width
            ub[i] = q_fixed[i] + fixed_half_width

    # Safety check.
    if np.any(lb >= ub):
        bad = np.where(lb >= ub)[0]
        raise ValueError(f"Invalid bounds at indices {bad}: lb >= ub")

    return HPolyhedron.MakeBox(lb, ub), lb, ub


slice_box, slice_lb, slice_ub = make_full_dimensional_slice_box(
    plant=plant,
    q_fixed=q_grasp,
    active_indices=active_indices,
    fixed_half_width=1e-4,   # try 1e-5 later if this works
)

# %% [markdown]
# ### Run Clique-Cover IRIS inside that slice/bounding region

# %%
from pydrake.geometry.optimization import IrisOptions

iris_options = IrisOptions()
iris_options.bounding_region = slice_box
iris_options.require_sample_point_is_contained = True

# Since this is called from clique cover, Drake recommends using only one
# internal IRIS iteration to avoid discarding clique information.
iris_options.iteration_limit = 1

iris_options.configuration_space_margin = 1e-5
iris_options.termination_threshold = -1
iris_options.relative_termination_threshold = -1
iris_options.random_seed = 1234
iris_options.mixing_steps = 50

options = IrisFromCliqueCoverOptions()
options.iris_options = iris_options
options.coverage_termination_threshold = 0.99
options.num_points_per_visibility_round = 500
options.num_points_per_coverage_check = 2000
options.parallelism = Parallelism(num_threads=8)

regions_4d_slice_10d = IrisInConfigurationSpaceFromCliqueCover(
    checker,
    options,
    generator,
    [],
)

print("Number of 10D slice regions:", len(regions_4d_slice_10d))
print("Ambient dimension:", regions_4d_slice_10d[0].ambient_dimension())
# Out:
# INFO:drake:Current Fraction of Domain Covered = 0
# INFO:drake:IrisFromCliqueCover Iteration 1/100
# INFO:drake:IrisNp iteration 0
# INFO:drake: Checking panda_hand::Sphere_2 against bottle_cap::collision_cap has already required 50 counter-example searches; still searching...
# INFO:drake: Finished checking panda_hand::Sphere_2 against bottle_cap::collision_cap after 169 counter-example searches.
# INFO:drake: Checking panda_hand::Sphere_4 against bottle_cap::collision_cap has already required 50 counter-example searches; still searching...
# INFO:drake: Finished checking panda_hand::Sphere_4 against bottle_cap::collision_cap after 169 counter-example searches.
# INFO:drake: Checking panda_hand::Sphere_3 against bottle_cap::collision_cap has already required 50 counter-example searches; still searching...
# INFO:drake: Finished checking panda_hand::Sphere_3 against bottle_cap::collision_cap after 355 counter-example searches.

# %% [markdown]
# ## Walk around c-free polytope

# %%
def walk_around_cfree_regions(q_start, regions, num_steps=10):
    """
    Walk around the c-free regions starting from q_start.
    For each step, randomly select a region and sample a point within it.
    """
    current_q = q_start.copy()
    path = [current_q.copy()]

    for step in range(num_steps):
        # Randomly select a region
        region_idx = np.random.randint(len(regions))
        region = regions[region_idx]

        # Sample a point within the selected region
        A = region.A()
        b = region.b()

        # Use quadprog to sample a point within the polytope defined by Ax <= b
        # We will solve a quadratic program to find a feasible point
        n_vars = A.shape[1]
        P = np.eye(n_vars)  # Identity matrix for the quadratic term
        q = np.zeros(n_vars)  # Zero vector for the linear term

        # Solve the quadratic program: minimize (1/2)x^T P x + q^T x subject to Ax <= b
        try:
            sol = quadprog.solve_qp(P, q, A.T, b)[0]
            current_q = sol
            path.append(current_q.copy())
            print(f"Step {step + 1}: Moved to region {region_idx}, new q: {current_q}")
        except Exception as e:
            print(f"Step {step + 1}: Failed to sample from region {region_idx}, error: {e}")

    return path



def is_q_within_any_region(q, regions):
    for region in regions:
        if np.all(region.A() @ q <= region.b()):
            return True
    return False


def find_any_q_within_regions(regions):
    for region in regions:
        # Sample a point within the region using quadprog
        A = region.A()
        b = region.b()
        n_vars = A.shape[1]
        P = np.eye(n_vars)  # Identity matrix for the quadratic term
        q = np.zeros(n_vars)  # Zero vector for the linear term

        try:
            sol = quadprog.solve_qp(P, q, A.T, b)[0]
            return sol
        except Exception as e:
            print(f"Failed to sample from region, error: {e}")
    return None

q_start = find_any_q_within_regions(regions)




print("Starting walk around c-free regions from q_start:", q_start)
assert is_q_within_any_region(q_start, regions), "q_start is not within any c-free region!"

walk_path = walk_around_cfree_regions(q_start=q_start, regions=regions, num_steps=10)
# Out:
# Failed to sample from region, error: constraints are inconsistent, no solution
# Failed to sample from region, error: constraints are inconsistent, no solution
# Starting walk around c-free regions from q_start: None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 66
#      62
#      63
#      64
#      65 print("Starting walk around c-free regions from q_start:", q_start)
# ---> 66 assert is_q_within_any_region(q_start, regions), "q_start is not within any c-free region!"
#      67
#      68 walk_path = walk_around_cfree_regions(q_start=q_start, regions=regions, num_steps=10)
#      69
#
# Cell In[53], line 39, in is_q_within_any_region(q, regions)
#      37 def is_q_within_any_region(q, regions):
#      38     for region in regions:
# ---> 39         if np.all(region.A() @ q <= region.b()):
#      40             return True
#      41     return False
#
# ValueError: matmul: Input operand 1 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)

# %% [markdown]
# # Trajectory Generation

# %% [markdown]
# ### Traj to grasp pose
#
# Traverse the c-free regions until the feasible grasping configuration is reached. Then generate trajectory from current configuration to goal configuration.
